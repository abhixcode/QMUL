# %%
import torch
import numpy
import matplotlib.pyplot as plt

#Creating a tensor of 3 rows and 2 columns of 1s.
x = torch.ones(3,2)
print(x)

#creating a tensor of 3 rows and 2 columns of 0s.
y = torch.zeros(3,2)
print(y)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
torch.manual_seed(2)
#generate tensor randomly
x = torch.rand(3,2)
print(x)

#generate tensor from random normal distribution
y = torch.randn(3,2)
print(y)
# Out:
# tensor([[0.6147, 0.3810],
#         [0.6371, 0.4745],
#         [0.7136, 0.6190]])
# tensor([[-2.1409, -0.5534],
#         [-0.5000, -0.0815],
#         [-0.1633,  1.5277]])

# %%
x = torch.tensor([[1, 2], [3, 4], [5, 6]])
print(x[:, 1]) # Every row, only the last column
print(x[0, :]) # Every column in first row

y = x[1, 1] # take the element in first row and first column and create a another tensor
print(y)

y = x.view(2, 3) #reshaping to 2 rows and 3 columns
print(y)
# Out:
# tensor([2, 4, 6])
# tensor([1, 2])
# tensor(4)
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x = torch.tensor([[1, 2], [3, 4], [5, 6]])
y = x.view(3,-1)
print(y)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
#Create two tensors
x = torch.ones([3, 2])
y = torch.ones([3, 2])

#adding two tensors
z = x + y #method 1
z = torch.add(x,y) #method 2
print(z)

#subtracting two tensors
z = x - y #method 1
torch.sub(x,y) #method 2
print(z)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
import numpy as np

x = torch.linspace(0 , 1, steps = 5)    #creating a tensor using linspace
print(x)
x_np = x.numpy() #convert tensor to numpy
print(x_np)

print(type(x), type(x_np)) #check the types 

a = np.random.randn(5)    #generate a random numpy array
print(a)
a_pt = torch.from_numpy(a) #convert numpy array to a tensor
print(a_pt)
print(type(a), type(a_pt))
# Out:
# tensor([0.0000, 0.2500, 0.5000, 0.7500, 1.0000])
# [0.   0.25 0.5  0.75 1.  ]
# <class 'torch.Tensor'> <class 'numpy.ndarray'>
# [ 1.8649027  -0.47298774 -0.72324801  1.00714824  0.25973602]
# tensor([ 1.8649, -0.4730, -0.7232,  1.0071,  0.2597], dtype=torch.float64)
# <class 'numpy.ndarray'> <class 'torch.Tensor'>

# %%
print(torch.cuda.device_count())

#print(torch.cuda.get_device_name(0))
# Out:
# 0
